# %%
import pandas as pd

df1 = pd.read_csv('Pizza_Sale - pizza_sales.csv')
df2 = pd.read_csv('Pizza_ingredients - Pizza_ingredients.csv')
df1 = df1.drop(['pizza_id','order_id','pizza_category','pizza_size','order_time','unit_price','total_price'],axis = 1)

#df1['total_price'] = df1.apply(lambda row: row['quantity'] * row['unit_price'] if pd.isna(row['total_price']) else row['total_price'], axis=1)

# %%
def parse_date(date_str):
    for fmt in ("%d/%m/%Y", "%d-%m-%Y", "%m/%d/%Y"):
        try:
            return pd.to_datetime(date_str, format=fmt, dayfirst=True)
        except ValueError:
            continue
    return pd.NaT

# Apply the function to the 'order_date' column
df1['order_date'] = df1['order_date'].apply(parse_date)

# %%
df1['week_number'] = df1['order_date'].dt.isocalendar().week

# %%
df1
# Out:
#        pizza_name_id  quantity order_date  \
# 0         hawaiian_m         1 2015-01-01
# 1      classic_dlx_m         1 2015-01-01
# 2      five_cheese_l         1 2015-01-01
# 3        ital_supr_l         1 2015-01-01
# 4         mexicana_m         1 2015-01-01
# ...              ...       ...        ...
# 48615  ckn_alfredo_m         1 2015-12-31
# 48616  four_cheese_l         1 2015-12-31
# 48617   napolitana_s         1 2015-12-31
# 48618     mexicana_l         1 2015-12-31
# 48619      bbq_ckn_s         1 2015-12-31
#
#                                        pizza_ingredients  \
# 0               Sliced Ham, Pineapple, Mozzarella Cheese
# 1      Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2      Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3      Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4      Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# ...                                                  ...
# 48615  Chicken, Red Onions, Red Peppers, Mushrooms, A...
# 48616  Ricotta Cheese, Gorgonzola Piccante Cheese, Mo...
# 48617  Tomatoes, Anchovies, Green Olives, Red Onions,...
# 48618  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# 48619  Barbecued Chicken, Red Peppers, Green Peppers,...
#
#                        pizza_name  week_number
# 0              The Hawaiian Pizza            1
# 1        The Classic Deluxe Pizza            1
# 2           The Five Cheese Pizza            1
# 3       The Italian Supreme Pizza            1
# 4              The Mexicana Pizza            1
# ...                           ...          ...
# 48615   The Chicken Alfredo Pizza           53
# 48616       The Four Cheese Pizza           53
# 48617        The Napolitana Pizza           53
# 48618          The Mexicana Pizza           53
# 48619  The Barbecue Chicken Pizza           53
#
# [48620 rows x 6 columns]

# %%
df1.isna().sum()
# Out:
# pizza_name_id        0
# quantity             0
# order_date           0
# pizza_ingredients    0
# pizza_name           0
# week_number          0
# dtype: int64

# %%
pizza_dict = df2.set_index('pizza_name_id')['pizza_name'].to_dict()
df1['pizza_name'] = df1.apply(lambda row: pizza_dict[row['pizza_name_id']] if pd.isna(row['pizza_name']) else row['pizza_name'], axis=1)

# %%
ingredient_dict = df2.set_index('pizza_name')['pizza_ingredients'].to_dict()
df1['pizza_ingredients'] = df1.apply(lambda row: ingredient_dict[row['pizza_name']] if pd.isna(row['pizza_ingredients']) else row['pizza_ingredients'], axis=1)

# %%
ingredient_dict = df2.set_index('pizza_name')['pizza_name_id'].to_dict()
df1['pizza_name_id'] = df1.apply(lambda row: ingredient_dict[row['pizza_name']] if pd.isna(row['pizza_name_id']) else row['pizza_name_id'], axis=1)

# %%
df1
# Out:
#        pizza_name_id  quantity order_date  \
# 0         hawaiian_m         1 2015-01-01
# 1      classic_dlx_m         1 2015-01-01
# 2      five_cheese_l         1 2015-01-01
# 3        ital_supr_l         1 2015-01-01
# 4         mexicana_m         1 2015-01-01
# ...              ...       ...        ...
# 48615  ckn_alfredo_m         1 2015-12-31
# 48616  four_cheese_l         1 2015-12-31
# 48617   napolitana_s         1 2015-12-31
# 48618     mexicana_l         1 2015-12-31
# 48619      bbq_ckn_s         1 2015-12-31
#
#                                        pizza_ingredients  \
# 0               Sliced Ham, Pineapple, Mozzarella Cheese
# 1      Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2      Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3      Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4      Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# ...                                                  ...
# 48615  Chicken, Red Onions, Red Peppers, Mushrooms, A...
# 48616  Ricotta Cheese, Gorgonzola Piccante Cheese, Mo...
# 48617  Tomatoes, Anchovies, Green Olives, Red Onions,...
# 48618  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# 48619  Barbecued Chicken, Red Peppers, Green Peppers,...
#
#                        pizza_name  week_number
# 0              The Hawaiian Pizza            1
# 1        The Classic Deluxe Pizza            1
# 2           The Five Cheese Pizza            1
# 3       The Italian Supreme Pizza            1
# 4              The Mexicana Pizza            1
# ...                           ...          ...
# 48615   The Chicken Alfredo Pizza           53
# 48616       The Four Cheese Pizza           53
# 48617        The Napolitana Pizza           53
# 48618          The Mexicana Pizza           53
# 48619  The Barbecue Chicken Pizza           53
#
# [48620 rows x 6 columns]

# %%
df1.to_csv('Sales.csv',index = False)

# %%
df2
# Out:
#     pizza_name_id                         pizza_name  pizza_ingredients  \
# 0       bbq_ckn_l         The Barbecue Chicken Pizza  Barbecued Chicken
# 1       bbq_ckn_l         The Barbecue Chicken Pizza        Red Peppers
# 2       bbq_ckn_l         The Barbecue Chicken Pizza      Green Peppers
# 3       bbq_ckn_l         The Barbecue Chicken Pizza           Tomatoes
# 4       bbq_ckn_l         The Barbecue Chicken Pizza         Red Onions
# ..            ...                                ...                ...
# 513  veggie_veg_s  The Vegetables + Vegetables Pizza      Green Peppers
# 514  veggie_veg_s  The Vegetables + Vegetables Pizza         Red Onions
# 515  veggie_veg_s  The Vegetables + Vegetables Pizza           Zucchini
# 516  veggie_veg_s  The Vegetables + Vegetables Pizza            Spinach
# 517  veggie_veg_s  The Vegetables + Vegetables Pizza             Garlic
#
#      Items_Qty_In_Grams
# 0                  40.0
# 1                  15.0
# 2                  20.0
# 3                  30.0
# 4                  60.0
# ..                  ...
# 513                20.0
# 514                20.0
# 515                10.0
# 516                15.0
# 517                 5.0
#
# [518 rows x 4 columns]

# %%
df2.isna().sum()
# Out:
# pizza_name_id         0
# pizza_name            0
# pizza_ingredients     0
# Items_Qty_In_Grams    4
# dtype: int64

# %%
nan_pizza_name_rows = df2[df2['Items_Qty_In_Grams'].isna()]
nan_pizza_name_rows
# Out:
# Empty DataFrame
# Columns: [pizza_name_id, pizza_name, pizza_ingredients, Items_Qty_In_Grams]
# Index: []

# %%
first_nan_index = df2['Items_Qty_In_Grams'].isna().idxmax()
df2.at[first_nan_index, 'Items_Qty_In_Grams'] = 25

# %%
first_nan_index = df2['Items_Qty_In_Grams'].isna().idxmax()
df2.at[first_nan_index, 'Items_Qty_In_Grams'] = 60

# %%
first_nan_index = df2['Items_Qty_In_Grams'].isna().idxmax()
df2.at[first_nan_index, 'Items_Qty_In_Grams'] = 40

# %%
first_nan_index = df2['Items_Qty_In_Grams'].isna().idxmax()
df2.at[first_nan_index, 'Items_Qty_In_Grams'] = 20

# %%
df2.to_csv("Ingre.csv",index = False)

# %%
weeknumber quantity date
